# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
df_comment_des = pd.read_csv('/content/drive/MyDrive/Carwow-Youtube-Analysis/Notebook - Copy/df_comments_des.csv')
df_videos_des = pd.read_csv('/content/drive/MyDrive/Carwow-Youtube-Analysis/Notebook - Copy/df_videos_des.csv')

# %%
df_comment = pd.read_csv('/content/drive/MyDrive/Carwow-Youtube-Analysis/df_comments.csv')
df_videos = pd.read_csv('/content/drive/MyDrive/Carwow-Youtube-Analysis/Notebook - Copy/df_videos.csv')

# %%
df_comment_des.info()
df_comment_des.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67782 entries, 0 to 67781
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 67782 non-null  object
#  1   video_id           67782 non-null  object
#  2   text               67782 non-null  object
#  3   timestamp          67782 non-null  int64
#  4   author             67782 non-null  object
#  5   parent             67782 non-null  object
#  6   preprocessed_text  66565 non-null  object
#  7   updated_text       65988 non-null  object
#  8   sentiment_score    67782 non-null  int64
# dtypes: int64(2), object(7)
# memory usage: 4.7+ MB
#                            id     video_id  \
# 0  UgyS35pBIMCQSsm3Zvh4AaABAg  9XT5eC1kfOg
# 1  Ugw83ZMjFdlm9ML2ZS14AaABAg  9XT5eC1kfOg
# 2  UgxvQF_oGsqy4ka6OVl4AaABAg  9XT5eC1kfOg
# 3  UgwmJ_P8n06ZrHToEjR4AaABAg  9XT5eC1kfOg
# 4  UgwIwBeUy_GhVxvBpIV4AaABAg  9XT5eC1kfOg
#
# ...

# %%
df_comment_des.fillna(' ', inplace=True)

# %%
df_videos_des.info()
df_videos_des.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17 entries, 0 to 16
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             17 non-null     object
#  1   title          17 non-null     object
#  2   duration       17 non-null     int64
#  3   view_count     17 non-null     int64
#  4   webpage_url    17 non-null     object
#  5   categories     17 non-null     object
#  6   comment_count  17 non-null     int64
#  7   like_count     17 non-null     int64
#  8   tags           17 non-null     object
#  9   upload_date    17 non-null     int64
# dtypes: int64(5), object(5)
# memory usage: 1.5+ KB
#             id                                              title  duration  \
# 0  9XT5eC1kfOg      1200hp Corvette C8 v Model S Plaid: DRAG RACE       980
# 1  aWJw2bazjBw                 BMW M3 Touring v BMW M8: DRAG RACE      1070
# ...

# %%
df_comment.info()
df_comment.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 643662 entries, 0 to 643661
# Data columns (total 9 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   id                 643662 non-null  object
#  1   video_id           643662 non-null  object
#  2   text               643662 non-null  object
#  3   timestamp          643662 non-null  int64
#  4   author             643662 non-null  object
#  5   parent             643662 non-null  object
#  6   preprocessed_text  631247 non-null  object
#  7   updated_text       626056 non-null  object
#  8   sentiment_score    643662 non-null  int64
# dtypes: int64(2), object(7)
# memory usage: 44.2+ MB
#                                                   id     video_id  \
# 0                         Ugxw9m2mUd_epG8Bk314AaABAg  Rr5bC-4XmP8
# 1  Ugxw9m2mUd_epG8Bk314AaABAg.9tJ5AbOlzO79tJ5VJM6N_I  Rr5bC-4XmP8
# 2  Ugxw9m2mUd_epG8Bk314AaABAg.9tJ5AbOlzO79tJ5YUVNfu9  Rr5bC-4XmP8
# ...

# %%
df_videos.info()
df_videos.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 227 entries, 0 to 226
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     227 non-null    int64
#  1   id             227 non-null    object
#  2   title          227 non-null    object
#  3   duration       227 non-null    int64
#  4   view_count     227 non-null    int64
#  5   webpage_url    227 non-null    object
#  6   categories     227 non-null    object
#  7   comment_count  227 non-null    int64
#  8   like_count     227 non-null    int64
#  9   tags           227 non-null    object
#  10  upload_date    227 non-null    int64
# dtypes: int64(6), object(5)
# memory usage: 19.6+ KB
#    Unnamed: 0           id                                              title  \
# 0           0  Rr5bC-4XmP8  1,000hp AWD Honda v Porsche 918 Spyder: DRAG RACE
# 1           1  yH2ysQB4HCU  1,000hp M5 v 1,000hp 911 Turbo v Model S Plaid...
# ...

# %%
df_videos.drop(columns='Unnamed: 0', inplace=True)

# %%
df1 = df_videos
df2 = df_videos_des
df_videos_combined = pd.concat([df1, df2], ignore_index=True)
df_videos_combined.info()
df_videos_combined.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             244 non-null    object
#  1   title          244 non-null    object
#  2   duration       244 non-null    int64
#  3   view_count     244 non-null    int64
#  4   webpage_url    244 non-null    object
#  5   categories     244 non-null    object
#  6   comment_count  244 non-null    int64
#  7   like_count     244 non-null    int64
#  8   tags           244 non-null    object
#  9   upload_date    244 non-null    int64
# dtypes: int64(5), object(5)
# memory usage: 19.2+ KB
#             id                                              title  duration  \
# 0  Rr5bC-4XmP8  1,000hp AWD Honda v Porsche 918 Spyder: DRAG RACE       935
# 1  yH2ysQB4HCU  1,000hp M5 v 1,000hp 911 Turbo v Model S Plaid...      1108
# ...

# %%
df1 = df_comment
df2 = df_comment_des
df_comments_combined = pd.concat([df1, df2], ignore_index=True)

df_comments_combined.info()
df_comments_combined.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 711444 entries, 0 to 711443
# Data columns (total 9 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   id                 711444 non-null  object
#  1   video_id           711444 non-null  object
#  2   text               711444 non-null  object
#  3   timestamp          711444 non-null  int64
#  4   author             711444 non-null  object
#  5   parent             711444 non-null  object
#  6   preprocessed_text  699029 non-null  object
#  7   updated_text       693838 non-null  object
#  8   sentiment_score    711444 non-null  int64
# dtypes: int64(2), object(7)
# memory usage: 48.9+ MB
#                                                   id     video_id  \
# 0                         Ugxw9m2mUd_epG8Bk314AaABAg  Rr5bC-4XmP8
# 1  Ugxw9m2mUd_epG8Bk314AaABAg.9tJ5AbOlzO79tJ5VJM6N_I  Rr5bC-4XmP8
# 2  Ugxw9m2mUd_epG8Bk314AaABAg.9tJ5AbOlzO79tJ5YUVNfu9  Rr5bC-4XmP8
# ...

# %%
df_comments_combined.fillna(' ', inplace=True)

# %%
df_comments_combined.info()
df_comments_combined.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 711444 entries, 0 to 711443
# Data columns (total 9 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   id                 711444 non-null  object
#  1   video_id           711444 non-null  object
#  2   text               711444 non-null  object
#  3   timestamp          711444 non-null  int64
#  4   author             711444 non-null  object
#  5   parent             711444 non-null  object
#  6   preprocessed_text  711444 non-null  object
#  7   updated_text       711444 non-null  object
#  8   sentiment_score    711444 non-null  int64
# dtypes: int64(2), object(7)
# memory usage: 48.9+ MB
#                                                   id     video_id  \
# 0                         Ugxw9m2mUd_epG8Bk314AaABAg  Rr5bC-4XmP8
# 1  Ugxw9m2mUd_epG8Bk314AaABAg.9tJ5AbOlzO79tJ5VJM6N_I  Rr5bC-4XmP8
# 2  Ugxw9m2mUd_epG8Bk314AaABAg.9tJ5AbOlzO79tJ5YUVNfu9  Rr5bC-4XmP8
# ...

# %%
df_videos_combined.to_csv('/content/drive/MyDrive/Carwow-Youtube-Analysis/Notebook - Copy/df_videos_combined.csv', index=False)
df_comments_combined.to_csv('/content/drive/MyDrive/Carwow-Youtube-Analysis/Notebook - Copy/df_coments_combined.csv', index=False)

# %% [markdown]
# # 2

# %%
df_com1 = pd.read_csv('/content/drive/MyDrive/Carwow-Youtube-Analysis/Notebook - Copy/df_coments_combined.csv')
df_com2 = pd.read_csv('/content/drive/MyDrive/Carwow-Youtube-Analysis/Notebook - Copy/df_comments_combined.csv')

# %%
df_com1.info()
df_com1.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 711444 entries, 0 to 711443
# Data columns (total 9 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   id                 711444 non-null  object
#  1   video_id           711444 non-null  object
#  2   text               711444 non-null  object
#  3   timestamp          711444 non-null  int64
#  4   author             711444 non-null  object
#  5   parent             711444 non-null  object
#  6   preprocessed_text  711444 non-null  object
#  7   updated_text       711444 non-null  object
#  8   sentiment_score    711444 non-null  int64
# dtypes: int64(2), object(7)
# memory usage: 48.9+ MB
#                                                   id     video_id  \
# 0                         Ugxw9m2mUd_epG8Bk314AaABAg  Rr5bC-4XmP8
# 1  Ugxw9m2mUd_epG8Bk314AaABAg.9tJ5AbOlzO79tJ5VJM6N_I  Rr5bC-4XmP8
# 2  Ugxw9m2mUd_epG8Bk314AaABAg.9tJ5AbOlzO79tJ5YUVNfu9  Rr5bC-4XmP8
# ...

# %%
df_com2.info()
df_com2.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 711444 entries, 0 to 711443
# Data columns (total 9 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   id                 711444 non-null  object
#  1   video_id           711444 non-null  object
#  2   text               711444 non-null  object
#  3   timestamp          711444 non-null  int64
#  4   author             711444 non-null  object
#  5   parent             711444 non-null  object
#  6   preprocessed_text  711444 non-null  object
#  7   updated_text       711444 non-null  object
#  8   sentiment_score    711444 non-null  int64
# dtypes: int64(2), object(7)
# memory usage: 48.9+ MB
#                                                   id     video_id  \
# 0                         Ugxw9m2mUd_epG8Bk314AaABAg  Rr5bC-4XmP8
# 1  Ugxw9m2mUd_epG8Bk314AaABAg.9tJ5AbOlzO79tJ5VJM6N_I  Rr5bC-4XmP8
# 2  Ugxw9m2mUd_epG8Bk314AaABAg.9tJ5AbOlzO79tJ5YUVNfu9  Rr5bC-4XmP8
# ...

# %%
df_com2.fillna(' ', inplace=True)

# %%
df_com2.to_csv('/content/drive/MyDrive/Carwow-Youtube-Analysis/Notebook - Copy/df_comments_combined.csv', index=False)
